# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math
from astropy.table import Table

M=10000
randoms=2*np.pi*np.random.rand(M)

plt.hist(np.cos(randoms),bins=100)
plt.show()
# Out:
# /tmp/ipykernel_13491/3704409275.py:13: RuntimeWarning: invalid value encountered in sqrt
#   plt.hist(1/np.sqrt(1-randoms**2),range=[-1.,1.])

# %%
xs=np.linspace(-1.,1.,num=1000)
ys=(1/np.sqrt(1-xs**2))
plt.plot(xs,ys)
plt.show()
# Out:
# /tmp/ipykernel_13491/3851262330.py:2: RuntimeWarning: divide by zero encountered in true_divide
#   ys=(1/np.sqrt(1-xs**2))
